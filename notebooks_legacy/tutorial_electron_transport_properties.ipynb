# %% [markdown]
# # Transport properties plot

# %%
pip install CRYSTALClear
# Out:
# Requirement already satisfied: CRYSTALClear in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (0.2.7)
# Requirement already satisfied: pymatgen in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from CRYSTALClear) (2024.8.9)
# Requirement already satisfied: mendeleev in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from CRYSTALClear) (1.1.0)
# Requirement already satisfied: ase in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from CRYSTALClear) (3.25.0)
# Requirement already satisfied: numpy>=1.19.5 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ase->CRYSTALClear) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ase->CRYSTALClear) (1.13.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ase->CRYSTALClear) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->CRYSTALClear) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->CRYSTALClear) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->CRYSTALClear) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->CRYSTALClear) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->CRYSTALClear) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->CRYSTALClear) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->CRYSTALClear) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->CRYSTALClear) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->CRYSTALClear) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.4->ase->CRYSTALClear) (3.23.0)
# Requirement already satisfied: six>=1.5 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase->CRYSTALClear) (1.17.0)
# Requirement already satisfied: Pygments<3.0.0,>=2.11.2 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from mendeleev->CRYSTALClear) (2.19.2)
# Requirement already satisfied: SQLAlchemy>=1.4.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from mendeleev->CRYSTALClear) (2.0.42)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from mendeleev->CRYSTALClear) (0.4.6)
# Requirement already satisfied: deprecated<2.0.0,>=1.2.14 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from mendeleev->CRYSTALClear) (1.2.18)
# Requirement already satisfied: pandas>=1.1.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from mendeleev->CRYSTALClear) (2.3.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.2 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from mendeleev->CRYSTALClear) (2.11.7)
# Requirement already satisfied: pyfiglet<0.9,>=0.8.post1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from mendeleev->CRYSTALClear) (0.8.post1)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from deprecated<2.0.0,>=1.2.14->mendeleev->CRYSTALClear) (1.17.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.9.2->mendeleev->CRYSTALClear) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.9.2->mendeleev->CRYSTALClear) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.9.2->mendeleev->CRYSTALClear) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.9.2->mendeleev->CRYSTALClear) (0.4.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pandas>=1.1.0->mendeleev->CRYSTALClear) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pandas>=1.1.0->mendeleev->CRYSTALClear) (2025.2)
# Requirement already satisfied: greenlet>=1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from SQLAlchemy>=1.4.0->mendeleev->CRYSTALClear) (3.2.4)
# Requirement already satisfied: joblib>=1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (1.5.1)
# Requirement already satisfied: monty>=2024.7.29 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (2025.3.3)
# Requirement already satisfied: networkx>=2.2 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (3.2.1)
# Requirement already satisfied: palettable>=3.3.3 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (3.3.3)
# Requirement already satisfied: plotly>=4.5.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (6.2.0)
# Requirement already satisfied: pybtex>=0.24.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (0.25.1)
# Requirement already satisfied: requests>=2.32 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (2.32.4)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (0.18.14)
# Requirement already satisfied: spglib>=2.5.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (2.6.0)
# Requirement already satisfied: sympy>=1.2 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (1.14.0)
# Requirement already satisfied: tabulate>=0.9 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (0.9.0)
# Requirement already satisfied: tqdm>=4.60 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (4.67.1)
# Requirement already satisfied: uncertainties>=3.1.4 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pymatgen->CRYSTALClear) (3.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from plotly>=4.5.0->pymatgen->CRYSTALClear) (2.0.1)
# Requirement already satisfied: PyYAML>=3.01 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pybtex>=0.24.0->pymatgen->CRYSTALClear) (6.0.2)
# Requirement already satisfied: latexcodec>=1.0.4 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pybtex>=0.24.0->pymatgen->CRYSTALClear) (3.0.1)
# Requirement already satisfied: importlib_metadata in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pybtex>=0.24.0->pymatgen->CRYSTALClear) (8.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from requests>=2.32->pymatgen->CRYSTALClear) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from requests>=2.32->pymatgen->CRYSTALClear) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from requests>=2.32->pymatgen->CRYSTALClear) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from requests>=2.32->pymatgen->CRYSTALClear) (2025.8.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ruamel.yaml>=0.17.0->pymatgen->CRYSTALClear) (0.2.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from sympy>=1.2->pymatgen->CRYSTALClear) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (6.30.1)
# Requirement already satisfied: comm>=0.1.1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (8.18.1)
# Requirement already satisfied: jupyter-client>=8.0.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (27.0.1)
# Requirement already satisfied: tornado>=6.2 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack-data in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing-extensions in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.14.1)
# Requirement already satisfied: exceptiongroup in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (1.3.0)
# Requirement already satisfied: pexpect>4.3 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: wcwidth in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from jupyter-client>=8.0.0->ipykernel) (8.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=8.0.0->ipykernel) (3.23.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/hostedtoolcache/Python/3.9.23/x64/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from CRYSTALClear.crystal_io import Properties_output
from CRYSTALClear import plot as CCplt

# %% [markdown]
# Read a seebeck files

# %%
seebeck = Properties_output().read_cry_seebeck('transport_zrnisn_SEEBECK.DAT')

# %%
seebeck1 = Properties_output().read_cry_seebeck('transport_zrnisn_antisito_SEEBECK.DAT')

# %% [markdown]
# Plot seebeck versus the chemical potential

# %%
CCplt.plot_cry_seebeck_potential(seebeck)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 CCplt.plot_cry_seebeck_potential(seebeck)
#
# TypeError: plot_cry_seebeck_potential() missing 2 required positional arguments: 'direction' and 'temperature'

# %% [markdown]
# Plot seebeck versus the charge carrier concentration

# %%
CCplt.plot_cry_seebeck_carrier(seebeck)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 CCplt.plot_cry_seebeck_carrier(seebeck)
#
# TypeError: plot_cry_seebeck_carrier() missing 2 required positional arguments: 'direction' and 'temperature'

# %% [markdown]
# Read a sigma files

# %%
sigma = Properties_output().read_cry_sigma('transport_zrnisn_SIGMA.DAT')

# %%
sigma1 = Properties_output().read_cry_sigma('transport_zrnisn_antisito_SIGMA.DAT')

# %% [markdown]
# Plot sigma versus the chemical potential

# %%
CCplt.plot_cry_sigma_potential(sigma)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 CCplt.plot_cry_sigma_potential(sigma)
#
# TypeError: plot_cry_sigma_potential() missing 2 required positional arguments: 'direction' and 'temperature'

# %% [markdown]
# Plot multiseebeck

# %%
CCplt.plot_cry_multiseebeck(seebeck, seebeck1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 CCplt.plot_cry_multiseebeck(seebeck, seebeck1)
#
# TypeError: plot_cry_multiseebeck() missing 2 required positional arguments: 'minpot' and 'maxpot'

# %% [markdown]
# Plot multisigma

# %%
CCplt.plot_cry_multisigma(sigma, sigma1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 CCplt.plot_cry_multisigma(sigma, sigma1)
#
# TypeError: plot_cry_multisigma() missing 2 required positional arguments: 'minpot' and 'maxpot'

# %% [markdown]
# Plot powerfactor

# %%
CCplt.plot_cry_powerfactor_potential(seebeck, sigma)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 CCplt.plot_cry_powerfactor_potential(seebeck, sigma)
#
# TypeError: plot_cry_powerfactor_potential() missing 2 required positional arguments: 'direction' and 'temperature'

# %% [markdown]
# Plot ZT

# %%
CCplt.plot_cry_zt(seebeck, sigma)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 CCplt.plot_cry_zt(seebeck, sigma)
#
# TypeError: plot_cry_zt() missing 3 required positional arguments: 'direction', 'temperature', and 'ktot'
